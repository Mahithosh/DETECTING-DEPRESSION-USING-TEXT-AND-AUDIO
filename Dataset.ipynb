# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd "drive/MyDrive/Dataset"

# %%
import os
os.chdir('drive/MyDrive/Dataset')

# %%
# !cd "drive/MyDrive/Dataset"

# %%
import numpy as np
import pandas as pd


dev = np.array(pd.read_csv('/content/drive/My Drive/Dataset/dev_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
print(len(dev))
test = np.array(pd.read_csv('/content/drive/My Drive/Dataset/full_test_split.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
print(len(test))
train = np.array(pd.read_csv('/content/drive/My Drive/Dataset/train_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
print(len(train))
for i in range(len(dev)):
      s = str(int(dev[i][0])) + "_P.zip"
      # !unzip -q {s} -d dev_data
for i in range(len(test)):
      s = str(int(test[i][0])) + "_P.zip"
      # !unzip -q {s} -d test_data
for i in range(len(train)):
      s = str(int(train[i][0])) + "_P.zip"
      # !unzip -q {s} -d train_data
# Out:
# 16
# 16
# 34
# unzip:  cannot find or open 420_P.zip, 420_P.zip.zip or 420_P.zip.ZIP.
# unzip:  cannot find or open 422_P.zip, 422_P.zip.zip or 422_P.zip.ZIP.
# unzip:  cannot find or open 436_P.zip, 436_P.zip.zip or 436_P.zip.ZIP.
# unzip:  cannot find or open 439_P.zip, 439_P.zip.zip or 439_P.zip.ZIP.
# unzip:  cannot find or open 440_P.zip, 440_P.zip.zip or 440_P.zip.ZIP.
# unzip:  cannot find or open 451_P.zip, 451_P.zip.zip or 451_P.zip.ZIP.
# unzip:  cannot find or open 458_P.zip, 458_P.zip.zip or 458_P.zip.ZIP.
# unzip:  cannot find or open 472_P.zip, 472_P.zip.zip or 472_P.zip.ZIP.
# unzip:  cannot find or open 476_P.zip, 476_P.zip.zip or 476_P.zip.ZIP.
# unzip:  cannot find or open 477_P.zip, 477_P.zip.zip or 477_P.zip.ZIP.
# unzip:  cannot find or open 482_P.zip, 482_P.zip.zip or 482_P.zip.ZIP.
# unzip:  cannot find or open 483_P.zip, 483_P.zip.zip or 483_P.zip.ZIP.
# unzip:  cannot find or open 484_P.zip, 484_P.zip.zip or 484_P.zip.ZIP.
# ...
